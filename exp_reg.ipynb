# %% [markdown]
# # Supervised Experiment (Regression)
#
# We will perform a small regression experiment using:
# - RandomForestRegressor
# - DecisionTreeRegressor
# - ForestBasedTree (FBT)
#
# Results will be saved to CSV, and we will display the “mean ± std” summary in Markdown form.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

import pandas as pd

from src.experiments.supervised import Experiment, FitReg, average_reg_metrics

from src.xtrees.model.fbt import ForestBasedTree

SEED = 1

# %% [markdown]
# ### 2.1 Define Parameters & Models

# %%
params_reg = {
    "meta-params": {
        "is_classification": False,
        "random_state": SEED,
        "use_cross_validation": True,
        "cv_folds": 3,
    },
    "data-params": [],
    "model-params": {},
}

rf_reg = RandomForestRegressor(
    random_state=params_reg["meta-params"]["random_state"],
    n_estimators=10,
    max_depth=5,
)
dt_reg = DecisionTreeRegressor(
    random_state=params_reg["meta-params"]["random_state"]
)

fbt_reg = ForestBasedTree(random_state=SEED, verbose=False)

fitreg = FitReg(SEED)

model_instances_reg = [rf_reg, dt_reg, fbt_reg]
fit_functions_reg  = [
    fitreg.fit_rf_regressor,
    fitreg.tune_dt_regressor,
    fitreg.fit_fbt_regressor,
]

# %% [markdown]
# ### 2.2 Run the Experiment & Save Results

# %%
exp_reg = Experiment(params_reg)

exp_reg.perform_experiments(
    num_datasets=10,
    overall_size="medium",
    information="mixed",
    prediction="mixed",
    model_instances=model_instances_reg,
    fit_functions=fit_functions_reg,
)

results_reg_df = exp_reg.assemble_results_dataframe()
results_reg_df.to_csv(f"data/results/reg_exp{SEED}.csv", index=False)
# Out:
# Dataset ID: 1
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1000          | 70            | 35            | 1             | 0.1000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 1                               | 2                               | 3
# mae              | 224.1692                        | 254.9309                        | 267.4533
# mse              | 77260.5245                      | 102386.2549                     | 110404.1597
# pred_time (s)    | 0.0008                          | 0.0002                          | 0.0164
# r2               | 0.342                           | 0.1265                          | 0.0577
# target_avg       | 0.1745                          | 0.1745                          | 0.1745
# target_mad       | 274.3775                        | 274.3775                        | 274.3775
# target_var       | 117681.7764                     | 117681.7764                     | 117681.7764
# train_time (s)   | 0.1163                          | 0.3816                          | 8.3072
#
#
#
# Dataset ID: 2
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1300          | 100           | 10            | 1             | 0.3000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 4                               | 5                               | 6
# mae              | 88.539                          | 108.7642                        | 125.181
# mse              | 12534.8632                      | 18489.3337                      | 24682.2811
# pred_time (s)    | 0.0009                          | 0.0003                          | 0.0236
# r2               | 0.6077                          | 0.421                           | 0.2287
# target_avg       | 1.4649                          | 1.4649                          | 1.4649
# target_mad       | 142.6059                        | 142.6059                        | 142.6059
# target_var       | 31946.0433                      | 31946.0433                      | 31946.0433
# train_time (s)   | 0.2212                          | 0.0792                          | 10.3194
#
#
#
# Dataset ID: 3
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 700           | 100           | 10            | 1             | 0.4000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 7                               | 8                               | 9
# mae              | 83.731                          | 99.0253                         | 108.9194
# mse              | 11177.6619                      | 15378.2011                      | 19147.7179
# pred_time (s)    | 0.0008                          | 0.0002                          | 0.0116
# r2               | 0.5753                          | 0.4182                          | 0.2775
# target_avg       | -1.7608                         | -1.7608                         | -1.7608
# target_mad       | 131.3358                        | 131.3358                        | 131.3358
# target_var       | 26672.0581                      | 26672.0581                      | 26672.0581
# train_time (s)   | 0.1252                          | 0.0482                          | 8.3199
#
#
#
# Dataset ID: 4
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 700           | 50            | 25            | 1             | 0.4000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 10                              | 11                              | 12
# mae              | 178.3382                        | 207.3062                        | 218.0609
# mse              | 50928.8789                      | 69057.5863                      | 74674.9121
# pred_time (s)    | 0.0006                          | 0.0003                          | 0.0119
# r2               | 0.3333                          | 0.0995                          | 0.0228
# target_avg       | -11.1148                        | -11.1148                        | -11.1148
# target_mad       | 222.6454                        | 222.6454                        | 222.6454
# target_var       | 76800.94                        | 76800.94                        | 76800.94
# train_time (s)   | 0.0621                          | 0.0309                          | 6.1704
#
#
#
# Dataset ID: 5
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1300          | 50            | 15            | 1             | 0.2000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 13                              | 14                              | 15
# mae              | 128.1315                        | 159.7654                        | 166.1857
# mse              | 25696.8172                      | 39003.1922                      | 43203.4607
# pred_time (s)    | 0.0008                          | 0.0003                          | 0.0219
# r2               | 0.5415                          | 0.3041                          | 0.2291
# target_avg       | -4.3245                         | -4.3245                         | -4.3245
# target_mad       | 188.5053                        | 188.5053                        | 188.5053
# target_var       | 56070.7839                      | 56070.7839                      | 56070.7839
# train_time (s)   | 0.1198                          | 0.0469                          | 8.6068
#
#
#
# Dataset ID: 6
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 700           | 70            | 35            | 1             | 0.3000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 16                              | 17                              | 18
# mae              | 197.7262                        | 247.5082                        | 241.1666
# mse              | 61147.9143                      | 92301.9217                      | 92819.7017
# pred_time (s)    | 0.0008                          | 0.0002                          | 0.0119
# r2               | 0.3722                          | 0.0475                          | 0.0544
# target_avg       | 6.7539                          | 6.7539                          | 6.7539
# target_mad       | 249.1202                        | 249.1202                        | 249.1202
# target_var       | 97814.791                       | 97814.791                       | 97814.791
# train_time (s)   | 0.0891                          | 0.034                           | 7.1869
#
#
#
# Dataset ID: 7
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1300          | 50            | 15            | 1             | 0.5000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 19                              | 20                              | 21
# mae              | 128.1315                        | 159.7654                        | 166.1857
# mse              | 25696.8172                      | 39003.1922                      | 43203.4607
# pred_time (s)    | 0.001                           | 0.0003                          | 0.0217
# r2               | 0.5415                          | 0.3041                          | 0.2291
# target_avg       | -4.3245                         | -4.3245                         | -4.3245
# target_mad       | 188.5053                        | 188.5053                        | 188.5053
# target_var       | 56070.7839                      | 56070.7839                      | 56070.7839
# train_time (s)   | 0.1212                          | 0.0475                          | 8.6318
#
#
#
# Dataset ID: 8
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 700           | 50            | 15            | 1             | 0.6000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 22                              | 23                              | 24
# mae              | 127.6097                        | 156.8451                        | 162.6118
# mse              | 25259.4022                      | 37263.6068                      | 41146.0548
# pred_time (s)    | 0.0007                          | 0.0002                          | 0.0123
# r2               | 0.4687                          | 0.216                           | 0.1359
# target_avg       | -5.0635                         | -5.0635                         | -5.0635
# target_mad       | 172.8444                        | 172.8444                        | 172.8444
# target_var       | 47742.4097                      | 47742.4097                      | 47742.4097
# train_time (s)   | 0.0625                          | 0.0313                          | 5.4118
#
#
#
# Dataset ID: 9
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1300          | 100           | 10            | 1             | 0.4000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 25                              | 26                              | 27
# mae              | 88.539                          | 108.7642                        | 125.181
# mse              | 12534.8632                      | 18489.3337                      | 24682.2811
# pred_time (s)    | 0.0009                          | 0.0003                          | 0.022
# r2               | 0.6077                          | 0.421                           | 0.2287
# target_avg       | 1.4649                          | 1.4649                          | 1.4649
# target_mad       | 142.6059                        | 142.6059                        | 142.6059
# target_var       | 31946.0433                      | 31946.0433                      | 31946.0433
# train_time (s)   | 0.2335                          | 0.0804                          | 10.5348
#
#
#
# Dataset ID: 10
# n_samples     | n_features    | n_informative | random_state  | tail_strength
# =============================================================================
# 1300          | 50            | 25            | 1             | 0.6000
# RandomForestRegressor
# DecisionTreeRegressor
# ForestBasedTree
# Metric          RandomForestRegressor           | DecisionTreeRegressor           | ForestBasedTree
# ===================================================================================================================
# experiment_id    | 28                              | 29                              | 30
# mae              | 163.612                         | 195.336                         | 218.6587
# mse              | 41954.264                       | 61288.4441                      | 73209.7203
# pred_time (s)    | 0.0008                          | 0.0002                          | 0.0216
# r2               | 0.4647                          | 0.2147                          | 0.0668
# target_avg       | -4.256                          | -4.256                          | -4.256
# target_mad       | 223.4226                        | 223.4226                        | 223.4226
# target_var       | 78478.6062                      | 78478.6062                      | 78478.6062
# train_time (s)   | 0.1177                          | 0.0374                          | 9.0786
#
#
# Completed 10 experiments.

# %% [markdown]
# ### 2.3 Display Averaged Regression Metrics

# %%
avg_reg_df = average_reg_metrics(results_reg_df)
print(avg_reg_df.to_markdown(index=False))
# Out:
# | model_name            | train_time (s)   | pred_time (s)   | normalized_mse   | r2            |
# |:----------------------|:-----------------|:----------------|:-----------------|:--------------|
# | DecisionTreeRegressor | 0.0817 ± 0.11    | 0.0003 ± 0.0    | 0.74 ± 0.14      | 0.2572 ± 0.14 |
# | ForestBasedTree       | 8.2568 ± 1.63    | 0.0175 ± 0.01   | 0.8458 ± 0.1     | 0.1531 ± 0.1  |
# | RandomForestRegressor | 0.1268 ± 0.06    | 0.0008 ± 0.0    | 0.5129 ± 0.11    | 0.4855 ± 0.11 |
